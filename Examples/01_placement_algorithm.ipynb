# %% [markdown]
# # Placement algorithm introduction

# %% [markdown]
# This notebook demonstrates how to use GLAES to systematically place objects (such as wind turbines) within a predefined study area.
#
# ### Workflow Overview:
# 1) **Create** file with available lands like in 00_basic_workflow.
# 2) **Distribute item placements** within the eligible regions
#     *  basic placement
#     *  spare the edges of a region
#     *  direction-dependent placements
#     *  get placement coordinates
#     *  use wind direction data for placements
#     *  spatially varying raster
#     *  individual placement areas

# %%
# Import GLAES
import geokit as gk
import matplotlib.pyplot as plt
import numpy as np

import glaes as gl

# %matplotlib inline

# other imports
from copy import copy

# %% [markdown]
# # 1. Create the land eligibility analysis

# %% [markdown]
# Here the eligibile land file from the first example notebook is recreated, for details have a look into 00_basic_workflow.

# %%
# Choose a region to operate on (Here, a predefined region for Aachen, Germany is used)
regionPath = gl._test_data_["aachenShapefile.shp"]

# Initialize ExclusionCalculator object
ec = gl.ExclusionCalculator(regionPath, srs=3035, pixelRes=100)

# Apply exclusions
ec.excludeRasterType(gl._test_data_["clc-aachen_clipped.tif"], value=(12, 22))
ec.excludeVectorType(
    gl._test_data_["aachenRoads.shp"], where="type='motorway' OR type='primary' OR type='trunk'", buffer=200
)

# Draw result
ec.draw()

# %% [markdown]
# Copy the ec object after land eligibility analysis.

# %%
# make a copy of the ec object so we can "reset" the ec object after distributing placements and have a "clean" ec again
ec_backup = copy(ec)

# %% [markdown]
# # 2. Distribute item placements within the eligible regions

# %% [markdown]
# ### Basic Placement
# **`separation`** specifies the minimal distance between two objects.

# %%
# Do placements
ec.distributeItems(separation=1000)

# Draw result
ec.draw()

# %% [markdown]
# ### Spare the edges of a region
# Sometimes it is needed to spare the edges of a region so that the separation distances are maintained also between placements of neighbouring regions using **`avoidRegionBorders=True`**.

# %%
# reset the ec object to remove the "old" placements from above
ec = copy(ec_backup)
# repeat the step above and set the argument avoidRegionBorders to True
ec.distributeItems(separation=1000, avoidRegionBorders=True)

# Draw result. In comparison to above you can see that no placements are distributed towards the edges of the region, you can also see that less items were distributed
ec.draw()

# %% [markdown]
# ### Direction-dependent placements
#
# By default, a single separation distance is used, meaning that the minimum spacing between two objects is the same in every direction.
#
# Alternatively, two separation distances can be specified using **`separation=(axial, transverse)`**, **`axialDirection`**:
#
# - **axial separation**: the minimum spacing along one chosen axis,
# - **transverse separation**: the minimum spacing along the axis perpendicular to it.
#
# The orientation of the axial axis is defined by the **`axialDirection`** parameter. The angle is measured counter-clockwise from East.
#
# <table style="border-collapse:collapse; border:none;">
# <tr style="border:none;">
# <td style="border:none; vertical-align:top; padding:0 1em 0 0;">
#
# - **0°**: axial axis runs east to west
# - **45°**: axial axis runs north-east to south-west
# - **90°**: axial axis runs north to south
#
# </td>
# <td style="border:none; vertical-align:top; padding:0;">
#
# <pre style="margin:0;">
#                    axialDirection = 45°
#
#                             axial
#                                ↗
#                               /
#                    ----------●----------
#                             /
#                           ↙
#                        axial
#                     transverse  transverse
#                         ↖           ↘
# </pre>
#
# </td>
# </tr>
# </table>
#
# Changing **`axialDirection`** simply rotates the two separation directions. The first value always belongs to the axial direction, and the second value to the perpendicular (transverse) direction.
#
# When two separation distances are provided, the boundary buffer is still applied equally in all directions. Its value is calculated as the average of the axial and transverse separation distances.

# %%
# reset the ec object again
ec = copy(ec_backup)
# do placements with "separation=(axial, transverse), axialDirection"
ec.distributeItems(separation=(1200, 600), axialDirection=45, avoidRegionBorders=True)

# Draw result
ec.draw()

# %% [markdown]
# ### Get the placements as XY coordinates

# %%
# print only the first 5 placements
print(ec.itemCoords[:5])

# %% [markdown]
# ### Use wind direction data for placements

# %%
ec.distributeItems(
    (1400, 600), axialDirection=r"data/ERA5_wind_direction_100m_mean_Aachen.tif", outputSRS=gk.srs.EPSG4326
)

ec.draw()

# %% [markdown]
# ### Create a spatially varying raster and use it to apply location-dependent spacing when distributing items.
#
# Instead of using a uniform separation distance, **`distributeItems()`** also supports the **`sepScaling`** parameter. This allows the separation distance to vary spatially based on a user-defined scaling raster. The scaling raster is supplied via the **`sepScaling`** parameter together with the base separation distance, allowing location-dependent spacing between placed items. A common application is to apply different placement densities based on land-cover or land-use classes, although any spatially varying raster can be used.

# %%
# Create a raster with values increasing from 50 to 200 from top to bottom
mat = np.zeros_like(ec.region.mask, dtype=np.uint8)
for i in range(mat.shape[0]):
    mat[i, :] = (200 - 50) * i / (mat.shape[0]) + 50

# Show the raster
h = plt.imshow(mat)
plt.colorbar(h)
plt.show()

# Convert the array into a raster used to scale separation distances
rotor_diam_raster = ec.region.createRaster(output="tmp/rotor_diameter.tif", data=mat)

# Place items using a variable spacing:
# effective spacing = separation × local raster value
points = ec.distributeItems(separation=8.0, sepScaling=rotor_diam_raster)

ec.draw()

# %% [markdown]
# ### Individual placement areas
#
# Additionally, the whole area can be divided into one area for each placement by using the **`distributeAreas`** function. Those can be saved as well.
# To call this function, first use the **`distributeItems`** function to create placements as elaborated above.

# %%
# 1) # Create the placement points and save them as a shapefile
points = ec.distributeItems(separation=1000)
ec.saveItems(output="tmp/individual_placement_points.shp")

# 2) Create placement areas (polygons around placed items) and save them as a shapefile
areas = ec.distributeAreas(minArea=300000)
ec.saveAreas(output="tmp/individual_placement_areas.shp")

# 3) Visualisation
ec.draw()
